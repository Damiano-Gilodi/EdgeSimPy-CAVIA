# %%
import pandas as pd

df = pd.read_pickle("processed_data/service_cavia_mean.pkl")
df
# Out:
#        Distribution          Scenario App_ms  Service_ID  \
# 0     deterministic  1_26_solution_v0   1SMM           0
# 1     deterministic  1_26_solution_v0   1SMM           1
# 2     deterministic  1_26_solution_v0   1SMM           2
# 3     deterministic  1_26_solution_v0   1SMM           3
# 4     deterministic  1_26_solution_v0   1SMM           4
# ...             ...               ...    ...         ...
# 2543        uniform  2_26_solution_v7   2SMS           5
# 2544        uniform  2_26_solution_v7   2SMS           6
# 2545        uniform  2_26_solution_v7   2SMS           7
# 2546        uniform  2_26_solution_v7   2SMS           8
# 2547        uniform  2_26_solution_v7   2SMS           9
#
#                      Node_Type  Cavia_Mean  Num_Runs  Empirical_Mean  \
# 0                        input         0.0      1000           0.000
# 1     perception_preprocessing         4.0      1000           4.000
# 2           feature_extraction         4.0      1000           4.000
# 3            context_awareness        10.0      1000          10.000
# 4                         avda         9.0      1000           9.000
# ...                        ...         ...       ...             ...
# 2543        feature_extraction         4.0      1000           3.455
# 2544         context_awareness        10.0      1000           9.452
# 2545     planning_and_decision         6.0      1000           5.660
# 2546                 actuation         4.0      1000           3.533
# 2547               destination         0.0      1000           0.000
#
#       Empirical_Std  Empirical_Min  Empirical_Max  Abs_Error  \
# 0          0.000000              0              0      0.000
# 1          0.000000              4              4      0.000
# 2          0.000000              4              4      0.000
# 3          0.000000             10             10      0.000
# 4          0.000000              9              9      0.000
# ...             ...            ...            ...        ...
# 2543       1.110499              2              5      0.545
# 2544       2.842847              5             14      0.548
# 2545       1.711528              3              8      0.340
# 2546       1.111822              2              5      0.467
# 2547       0.000000              0              0      0.000
#
#       Rel_Error_Percent
# 0              0.000000
# 1              0.000000
# 2              0.000000
# 3              0.000000
# 4              0.000000
# ...                 ...
# 2543          13.625000
# 2544           5.480000
# 2545           5.666667
# 2546          11.675000
# 2547           0.000000
#
# [2548 rows x 13 columns]

# %%
print(f"Total rows: {len(df)}")
print(f"Distributions: {df['Distribution'].nunique()}")
print(f"Scenarios: {df['Scenario'].nunique()}")
print(f"App: {df[['Scenario', 'App_ms']].drop_duplicates().shape[0]}")
print(f"Average percentage error: {df['Rel_Error_Percent'].mean():.2f}")
print(f"Maximum percentage error: {df['Rel_Error_Percent'].max():.2f}")
print(f"Average percentage error per distribution:\n {df.groupby('Distribution')['Rel_Error_Percent'].mean().round(2)}")
# Out:
# Total rows: 2548
# Distributions: 7
# Scenarios: 10
# App: 48
# Average percentage error: 5.28
# Maximum percentage error: 22.58
# Average percentage error per distribution:
#  Distribution
# deterministic         0.00
# exponential           4.00
# gamma_k2              5.78
# normal                6.74
# normal_wide           2.64
# normal_wide_trunc    11.07
# uniform               6.72
# Name: Rel_Error_Percent, dtype: float64

# %%
df_exp = df[df['Distribution'] == 'exponential']
df_exp.head(20)
# Out:
#     Distribution          Scenario App_ms  Service_ID  \
# 364  exponential  1_26_solution_v0   1SMM           0
# 365  exponential  1_26_solution_v0   1SMM           1
# 366  exponential  1_26_solution_v0   1SMM           2
# 367  exponential  1_26_solution_v0   1SMM           3
# 368  exponential  1_26_solution_v0   1SMM           4
# 369  exponential  1_26_solution_v0   1SMM           5
# 370  exponential  1_26_solution_v0   1SMS           0
# 371  exponential  1_26_solution_v0   1SMS           1
# 372  exponential  1_26_solution_v0   1SMS           2
# 373  exponential  1_26_solution_v0   1SMS           3
# 374  exponential  1_26_solution_v0   1SMS           4
# 375  exponential  1_26_solution_v0   1SMS           5
# 376  exponential  1_26_solution_v0   1SMS           6
# 377  exponential  1_26_solution_v0   1SSM           0
# 378  exponential  1_26_solution_v0   1SSM           1
# 379  exponential  1_26_solution_v0   1SSM           2
# 380  exponential  1_26_solution_v0   1SSM           3
# 381  exponential  1_26_solution_v0   1SSM           4
# 382  exponential  1_26_solution_v0   1SSM           5
# 383  exponential  1_26_solution_v0   1SSM           6
#
#                     Node_Type  Cavia_Mean  Num_Runs  Empirical_Mean  \
# 364                     input         0.0      1000           0.000
# 365  perception_preprocessing         4.0      1000           3.673
# 366        feature_extraction         4.0      1000           3.876
# 367         context_awareness        10.0      1000           9.603
# 368                      avda         9.0      1000           8.634
# 369               destination         0.0      1000           0.000
# 370                     input         0.0      1000           0.000
# 371  perception_preprocessing         4.0      1000           3.606
# 372        feature_extraction         4.0      1000           3.762
# 373         context_awareness        10.0      1000           9.061
# 374     planning_and_decision         6.0      1000           5.965
# 375                 actuation         4.0      1000           3.822
# 376               destination         0.0      1000           0.000
# 377                     input         0.0      1000           0.000
# 378  perception_preprocessing         4.0      1000           3.740
# 379        feature_extraction         4.0      1000           3.599
# 380             sensor_fusion         6.0      1000           5.424
# 381               map_content         5.0      1000           4.722
# 382                      avda         9.0      1000           8.477
# 383               destination         0.0      1000           0.000
#
#      Empirical_Std  Empirical_Min  Empirical_Max  Abs_Error  Rel_Error_Percent
# 364       0.000000              0              0      0.000           0.000000
# 365       3.718857              1             24      0.327           8.175000
# 366       3.729146              1             28      0.124           3.100000
# 367       9.624449              1             53      0.397           3.970000
# 368       9.108513              1             86      0.366           4.066667
# 369       0.000000              0              0      0.000           0.000000
# 370       0.000000              0              0      0.000           0.000000
# 371       3.699791              1             29      0.394           9.850000
# 372       3.860863              1             30      0.238           5.950000
# 373       9.648958              1             67      0.939           9.390000
# 374       5.873012              1             44      0.035           0.583333
# 375       3.752385              1             25      0.178           4.450000
# 376       0.000000              0              0      0.000           0.000000
# 377       0.000000              0              0      0.000           0.000000
# 378       3.867733              1             26      0.260           6.500000
# 379       3.615698              1             30      0.401          10.025000
# 380       6.101594              1             50      0.576           9.600000
# 381       4.941977              1             33      0.278           5.560000
# 382       8.054088              1             63      0.523           5.811111
# 383       0.000000              0              0      0.000           0.000000
