# %%
import pandas as pd

df = pd.read_pickle("processed_data/service_cavia_mean.pkl")
df
# Out:
#        Distribution          Scenario App_ms  Service_ID  \
# 0     deterministic  1_26_solution_v0   1SMM           0
# 1     deterministic  1_26_solution_v0   1SMM           1
# 2     deterministic  1_26_solution_v0   1SMM           2
# 3     deterministic  1_26_solution_v0   1SMM           3
# 4     deterministic  1_26_solution_v0   1SMM           4
# ...             ...               ...    ...         ...
# 2543        uniform  2_26_solution_v7   2SMS           5
# 2544        uniform  2_26_solution_v7   2SMS           6
# 2545        uniform  2_26_solution_v7   2SMS           7
# 2546        uniform  2_26_solution_v7   2SMS           8
# 2547        uniform  2_26_solution_v7   2SMS           9
#
#                      Node_Type  Cavia_Mean  Num_Runs  Empirical_Mean  \
# 0                        input         0.0       100            0.00
# 1     perception_preprocessing         4.0       100            4.00
# 2           feature_extraction         4.0       100            4.00
# 3            context_awareness        10.0       100           10.00
# 4                         avda         9.0       100            9.00
# ...                        ...         ...       ...             ...
# 2543        feature_extraction         4.0       100            3.42
# 2544         context_awareness        10.0       100            9.61
# 2545     planning_and_decision         6.0       100            5.70
# 2546                 actuation         4.0       100            3.51
# 2547               destination         0.0       100            0.00
#
#       Empirical_Std  Empirical_Min  Empirical_Max  Abs_Error  \
# 0          0.000000              0              0       0.00
# 1          0.000000              4              4       0.00
# 2          0.000000              4              4       0.00
# 3          0.000000             10             10       0.00
# 4          0.000000              9              9       0.00
# ...             ...            ...            ...        ...
# 2543       1.138668              2              5       0.58
# 2544       2.860017              5             14       0.39
# 2545       1.672716              3              8       0.30
# 2546       1.123621              2              5       0.49
# 2547       0.000000              0              0       0.00
#
#       Rel_Error_Percent
# 0                  0.00
# 1                  0.00
# 2                  0.00
# 3                  0.00
# 4                  0.00
# ...                 ...
# 2543              14.50
# 2544               3.90
# 2545               5.00
# 2546              12.25
# 2547               0.00
#
# [2548 rows x 13 columns]

# %%
print(f"Total rows: {len(df)}")
print(f"Distributions: {df['Distribution'].nunique()}")
print(f"Scenarios: {df['Scenario'].nunique()}")
print(f"App: {df[['Scenario', 'App_ms']].drop_duplicates().shape[0]}")
print(f"Average percentage error: {df['Rel_Error_Percent'].mean():.2f}")
print(f"Maximum percentage error: {df['Rel_Error_Percent'].max():.2f}")
print(f"Average percentage error per distribution:\n {df.groupby('Distribution')['Rel_Error_Percent'].mean().round(2)}")
# Out:
# Total rows: 2548
# Distributions: 7
# Scenarios: 10
# App: 48
# Average percentage error: 5.91
# Maximum percentage error: 34.00
# Average percentage error per distribution:
#  Distribution
# deterministic         0.00
# exponential           6.60
# gamma_k2              6.69
# normal                6.70
# normal_wide           3.52
# normal_wide_trunc    11.16
# uniform               6.70
# Name: Rel_Error_Percent, dtype: float64

# %%
df_exp = df[df['Distribution'] == 'exponential']
df_exp.head(20)
# Out:
#     Distribution          Scenario App_ms  Service_ID  \
# 364  exponential  1_26_solution_v0   1SMM           0
# 365  exponential  1_26_solution_v0   1SMM           1
# 366  exponential  1_26_solution_v0   1SMM           2
# 367  exponential  1_26_solution_v0   1SMM           3
# 368  exponential  1_26_solution_v0   1SMM           4
# 369  exponential  1_26_solution_v0   1SMM           5
# 370  exponential  1_26_solution_v0   1SMS           0
# 371  exponential  1_26_solution_v0   1SMS           1
# 372  exponential  1_26_solution_v0   1SMS           2
# 373  exponential  1_26_solution_v0   1SMS           3
# 374  exponential  1_26_solution_v0   1SMS           4
# 375  exponential  1_26_solution_v0   1SMS           5
# 376  exponential  1_26_solution_v0   1SMS           6
# 377  exponential  1_26_solution_v0   1SSM           0
# 378  exponential  1_26_solution_v0   1SSM           1
# 379  exponential  1_26_solution_v0   1SSM           2
# 380  exponential  1_26_solution_v0   1SSM           3
# 381  exponential  1_26_solution_v0   1SSM           4
# 382  exponential  1_26_solution_v0   1SSM           5
# 383  exponential  1_26_solution_v0   1SSM           6
#
#                     Node_Type  Cavia_Mean  Num_Runs  Empirical_Mean  \
# 364                     input         0.0       100            0.00
# 365  perception_preprocessing         4.0       100            3.66
# 366        feature_extraction         4.0       100            4.28
# 367         context_awareness        10.0       100            9.65
# 368                      avda         9.0       100            9.50
# 369               destination         0.0       100            0.00
# 370                     input         0.0       100            0.00
# 371  perception_preprocessing         4.0       100            3.62
# 372        feature_extraction         4.0       100            4.13
# 373         context_awareness        10.0       100            8.00
# 374     planning_and_decision         6.0       100            7.85
# 375                 actuation         4.0       100            3.74
# 376               destination         0.0       100            0.00
# 377                     input         0.0       100            0.00
# 378  perception_preprocessing         4.0       100            3.63
# 379        feature_extraction         4.0       100            3.41
# 380             sensor_fusion         6.0       100            5.54
# 381               map_content         5.0       100            4.65
# 382                      avda         9.0       100            8.22
# 383               destination         0.0       100            0.00
#
#      Empirical_Std  Empirical_Min  Empirical_Max  Abs_Error  Rel_Error_Percent
# 364       0.000000              0              0       0.00           0.000000
# 365       3.458907              1             18       0.34           8.500000
# 366       4.746248              1             28       0.28           7.000000
# 367       9.838468              1             50       0.35           3.500000
# 368      12.309559              1             86       0.50           5.555556
# 369       0.000000              0              0       0.00           0.000000
# 370       0.000000              0              0       0.00           0.000000
# 371       4.037151              1             29       0.38           9.500000
# 372       4.576300              1             28       0.13           3.250000
# 373       8.177328              1             41       2.00          20.000000
# 374       7.621574              1             44       1.85          30.833333
# 375       3.214927              1             15       0.26           6.500000
# 376       0.000000              0              0       0.00           0.000000
# 377       0.000000              0              0       0.00           0.000000
# 378       3.509453              1             16       0.37           9.250000
# 379       2.814447              1             15       0.59          14.750000
# 380       5.938098              1             35       0.46           7.666667
# 381       4.697678              1             24       0.35           7.000000
# 382       8.636989              1             63       0.78           8.666667
# 383       0.000000              0              0       0.00           0.000000
